# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/
# Out:
# /content/drive/My Drive

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# 'April Itinerary.gsheet'                                 MM/
# 'Causal and coincidence stimuli'/                        Papers/
#  Classes/                                                Projects/
#  ConceptualAlignmentLanguage.zip                        'VSS Poster'/
# 'Ensemble Representations - Column chart 1.gsheet'      'Week 13 sid copy.gdoc'
# 'Lab documents'/                                        'Week 7.gdoc'
# 'Methods and Results - ensemble representations .gdoc'   Writing/

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive'
